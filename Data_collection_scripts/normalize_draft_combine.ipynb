# %%
import pandas as pd

combine = pd.read_csv("../Stage_3/Datasets/draft_combine_stats.csv")

# %%
# Names and position are redundant, i think removing height is a good idea too
# even if its not redundant it complicates things as height and height_wo_shoes dont
# match
combine = combine.drop(
    columns = {
        "player_name", "last_name", "first_name", "position", "height_wo_shoes"
    }
)

# %%
combine = combine.rename(columns = {"player_id" : "PlayerID"})
combine.to_csv("../Stage_3/Datasets/bcnf_combine_stats.csv", index = False)
